# %%
import requests as req
from bs4 import BeautifulSoup

# %%
import selenium
from PIL import Image
import pandas as pd
import numpy as np
from selenium import webdriver
import time

# %%
"""
PATH = "/Users/victorpalanco/Downloads/chromedriver_2.exe"
driver = selenium.webdriver.Chrome(PATH)
driver.get('https://www.modeapp.com/')

driver = webdriver.Chrome(executable_path = PATH)
url = "https://www.google.com/"
driver.get(url)

driver.quit()
"""
FCA_flagged_prov = pd.read_csv('/Users/victorpalanco/Desktop/project-lewagon/data_19.csv')

# %%
FCA_flagged_prov['website'].head()
# Out:
# 0    ['https://cryptoforextrading50.com/']
# 1       ['www.cryptodigital-currency.com']
# 2               ['www.highstarinvest.com']
# 3           ['www.cryptoglobaltrade.live']
# 4            ['www.forexcryptopayout.com']
# Name: website, dtype: object

# %%
FCA_flagged_prov['website'][0]
# Out:
# "['https://cryptoforextrading50.com/']"

# %%
screenshots = []

# %%
# Screenshots
spare_websites = []
driver = webdriver.Chrome(executable_path = "/Users/victorpalanco/Downloads/chromedriver_2.exe")
for all_websites in FCA_flagged_prov['website']:
    if len(all_websites) > 1:
        for website in all_websites:
            url = all_websites[0]
            spare_websites.append(all_websites[1:])
        else:
            url = website
driver.get(url)
time.sleep(20)
#
driver.save_screenshot('ss.png')
screenshot = Image.open('ss.png')
screenshots.append(screenshot)
#ss.png upload to cloud
#screenshot.show()
screenshots[0]
# Out:
# /var/folders/yx/vnqmn48j7k1dnhx55c2zcxzh0000gn/T/ipykernel_2068/445368590.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = "/Users/victorpalanco/Downloads/chromedriver_2.exe")
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1308>

# %%
ls[1]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1314>

# %%
driver = webdriver.Chrome(executable_path = "/Users/victorpalanco/Downloads/chromedriver_2.exe")
url = "https://www.booking.com/index.html?aid=1743217"
driver.get(url)
text = driver.find_elements( by = "tag name", value = "body")
time.sleep(10)
final1 = text[0].get_attribute("innerText")
# Out:
# /var/folders/yx/vnqmn48j7k1dnhx55c2zcxzh0000gn/T/ipykernel_2068/2662657926.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = "/Users/victorpalanco/Downloads/chromedriver_2.exe")

# %%
final1
# Out:
# 'Skip to main content\nGBP\nChoose your currency. Your current currency is Pound sterling\nChoose your language. Your current language is English (UK)\nGet help with your reservation\nList your property\nRegister\nSign in\nOffer ends in 3 days\nSave 30% or more with\nBlack Friday Deals\n\nFrom seaside villas to city flats, book the perfect stay for less\n\nFind deals\nPlease type your destination\n\t\n+\nCheck-in month\nNovember 2022\nDecember 2022\nJanuary 2023\nFebruary 2023\nMarch 2023\nApril 2023\nMay 2023\nJune 2023\nJuly 2023\nAugust 2023\nSeptember 2023\nOctober 2023\nNovember 2023\nDecember 2023\nJanuary 2024\nFebruary 2024\nCheck-in day\nCheck-in\n\t\n+\nCheck-out month\nNovember 2022\nDecember 2022\nJanuary 2023\nFebruary 2023\nMarch 2023\nApril 2023\nMay 2023\nJune 2023\nJuly 2023\nAugust 2023\nSeptember 2023\nOctober 2023\nNovember 2023\nDecember 2023\nJanuary 2024\nFebruary 2024\nCheck-out day\nCheck-out\n\t\nRooms and occupancy\n2 adults \xa0·\xa0 0 children \xa0·\xa0 1
# ...
