# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support import expected_conditions as EC

import time
import numpy as np 
import pandas as pd

# %%
PATH='/Users/noemiefabry/code/alfab98/selenium-test/chromedriver.exe'

driver=webdriver.Chrome(PATH)
time.sleep(10)
driver.get("https://coinmarketcap.com/rankings/exchanges/")
# Out:
# /var/folders/lg/89sfsg8910b01r82ql_drktw0000gn/T/ipykernel_21241/3554923639.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(PATH)

# %%
l=[]
for i in driver.find_elements(By.CLASS_NAME,value='flexStart'):
    element=i.find_elements(By.TAG_NAME,value='a')
    l.append(element)
    #.get_attribute('href')
l
# Out:
# [[<selenium.webdriver.remote.webelement.WebElement (session="021ca1396cbceaa4332aea2902fe6f33", element="905690cb-9dbd-4575-8bda-b16b2dac0a5f")>,
#   <selenium.webdriver.remote.webelement.WebElement (session="021ca1396cbceaa4332aea2902fe6f33", element="c585e563-e9e2-4693-82d6-fd0b89819035")>],
#  [<selenium.webdriver.remote.webelement.WebElement (session="021ca1396cbceaa4332aea2902fe6f33", element="94ac0ea6-baec-425d-91a5-3e08e8ddc394")>],
#  [<selenium.webdriver.remote.webelement.WebElement (session="021ca1396cbceaa4332aea2902fe6f33", element="a6ffaa24-b24f-48b6-b15d-d166e0abb90c")>],
#  [<selenium.webdriver.remote.webelement.WebElement (session="021ca1396cbceaa4332aea2902fe6f33", element="ba6f6338-4427-408f-8553-bc21538e8803")>,
#   <selenium.webdriver.remote.webelement.WebElement (session="021ca1396cbceaa4332aea2902fe6f33", element="22bc5bca-d65b-4f23-9418-dabfa9243922")>],
# ...

# %%
lien=[]
for i in l :
    lien.append(i[0].get_attribute('href'))

# %%
lien
# Out:
# ['https://coinmarketcap.com/exchanges/binance/',
#  'https://coinmarketcap.com/exchanges/coinbase-exchange/',
#  'https://coinmarketcap.com/exchanges/kraken/',
#  'https://coinmarketcap.com/exchanges/kucoin/',
#  'https://coinmarketcap.com/exchanges/bitstamp/',
#  'https://coinmarketcap.com/exchanges/bitfinex/',
#  'https://coinmarketcap.com/exchanges/okx/',
#  'https://coinmarketcap.com/exchanges/gemini/',
#  'https://coinmarketcap.com/exchanges/coincheck/',
#  'https://coinmarketcap.com/exchanges/bitflyer/',
#  'https://coinmarketcap.com/exchanges/bybit/',
#  'https://coinmarketcap.com/exchanges/bithumb/',
#  'https://coinmarketcap.com/exchanges/gate-io/',
#  'https://coinmarketcap.com/exchanges/binance-us/',
#  'https://coinmarketcap.com/exchanges/bitget/',
#  'https://coinmarketcap.com/exchanges/crypto-com-exchange/',
#  'https://coinmarketcap.com/exchanges/huobi/',
#  'https://coinmarketcap.com/exchanges/bkex/',
#  'https://coinmarketcap.com/exchanges/mxc/',
# ...

# %%
driver2=webdriver.Chrome(PATH)
time.sleep(10)

link=[]
for i in lien :
    driver2.get(i)
    ul_li_list = driver2.find_elements(By.CLASS_NAME,value="cmc-details-panel-links")
    link.append(ul_li_list[0].find_elements(By.TAG_NAME,'a')[0].get_attribute('href'))
# Out:
# /var/folders/lg/89sfsg8910b01r82ql_drktw0000gn/T/ipykernel_21241/2606032958.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver2=webdriver.Chrome(PATH)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [70], line 8
#       6 driver2.get(i)
#       7 ul_li_list = driver2.find_elements(By.CLASS_NAME,value="cmc-details-panel-links")
# ----> 8 link.append(ul_li_list[0].find_elements(By.TAG_NAME,'a')[0].get_attribute('href'))
#
# IndexError: list index out of range

# %%
data1=pd.DataFrame(np.array(link))

# %%
data1.to_csv('/Users/noemiefabry/Desktop/Alex/crypto_legim.csv')

# %%
driver2.find_elements(By.TAG_NAME,'ul')

# %%
ul_li_list = driver2.find_elements(By.CLASS_NAME,value="cmc-details-panel-links")

# %%
ul_li_list[0].find_elements(By.TAG_NAME,'a')[0].get_attribute('href')
# Out:
# 'https://www.binance.com/'

# %%
for i in ul_li_list:
    i.find_elements(By.TAG_NAME,'a')

# %%
for i in driver2.find_elements(By.TAG_NAME,'ul'):
    print(i)
    try:
        
        test=i.find_elements(By.TAG_NAME,'a').get_attribute('href')
        print('cool')
    except:
        continue
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="a43d79f48aff7616cdfac37bd4fa101d", element="992416bc-ee59-461e-8cf6-109dad575b33")>
# <selenium.webdriver.remote.webelement.WebElement (session="a43d79f48aff7616cdfac37bd4fa101d", element="fabf2f1d-4bdf-42ad-809b-89f6339f435e")>
# <selenium.webdriver.remote.webelement.WebElement (session="a43d79f48aff7616cdfac37bd4fa101d", element="65e25bcd-6aaa-42ab-839d-e5ad4739193d")>
# <selenium.webdriver.remote.webelement.WebElement (session="a43d79f48aff7616cdfac37bd4fa101d", element="3356ad3c-aed2-4bdf-93c7-3635ec91c798")>
# <selenium.webdriver.remote.webelement.WebElement (session="a43d79f48aff7616cdfac37bd4fa101d", element="c32f8ac6-fdc2-4c0b-9b8c-d87a945619b9")>

# %%
print(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [57], line 1
# ----> 1 print(test)
#
# NameError: name 'test' is not defined

# %%
driver.find_elements(By.TAG_NAME,value='span')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="510303af405954814d74806b9dae6b6b", element="da7915e6-891e-4153-8df8-cd3f2e1962b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="510303af405954814d74806b9dae6b6b", element="8f9ca080-b8b3-4308-aaa7-edb0367ccc50")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="510303af405954814d74806b9dae6b6b", element="552e1aac-a055-457d-95fe-4f47e86dc950")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="510303af405954814d74806b9dae6b6b", element="2bf01c33-c170-46ad-8a3a-fdea42514f1d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="510303af405954814d74806b9dae6b6b", element="b21fe8e0-2488-43df-849f-03816c682865")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="510303af405954814d74806b9dae6b6b", element="5717b454-6448-4c55-a6c7-a5fa78433c9d")>,
# ...

# %%
pd.read_csv('/Users/noemiefabry/Downloads/mfi_csv_221129.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 pd.read_csv('/Users/noemiefabry/Downloads/mfi_csv_221129.csv')
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# !pwd
# Out:
# /Users/noemiefabry/code/alfab98/selenium-test
