# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support import expected_conditions as EC

import time
import numpy as np 
import pandas as pd

# %%
PATH='/Users/noemiefabry/code/alfab98/selenium-test/chromedriver.exe'

driver=webdriver.Chrome(PATH)

driver.get("https://bankchart.co.uk/catalogue/banks")
# Out:
# /var/folders/lg/89sfsg8910b01r82ql_drktw0000gn/T/ipykernel_25742/1373992102.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(PATH)

# %%
ul=driver.find_elements(By.TAG_NAME,value='ul')

# %%
l=[]
for i in ul:
    test=i.find_elements(By.TAG_NAME,'p')
    for j in test:
        l.append(j.text)

# %%
l
# Out:
# ['compare rates',
#  'Number of banks: 184',
#  'www.bank-abc.com/world/abcib/en/Pages/default.aspx',
#  'www.abnamro.com/uk',
#  'www.theaccessbankukltd.co.uk',
#  'www.adambank.com',
#  'www.adib.co.uk',
#  'www.uk.abchina.com/en/default.htm',
#  'www.ahliunited.com/uk/uk_contact.html',
#  'www.aibgb.co.uk',
#  'www.aldermore.co.uk',
#  'www.allfunds.com/en',
#  'www.allfunds.com/en',
#  'www.aib.ie',
#  'www.alpha-bank.uk',
#  'www.alrayanbank.co.uk',
#  'www.anz.com/unitedkingdom/en/personal',
#  'www.arabbank.com',
#  'www.arbuthnotlatham.co.uk',
#  'www.lhv.co.uk',
#  'www.atombank.co.uk',
#  'www.anz.com/institutional/global/united-kingdom/en',
#  'www.axisbankuk.co.uk',
#  'www.bbvauk.com',
#  'www.bradescoeuropa.eu/SiteBradescoEuropa/Europe-is-a-Customer/About-Bradesco-Europa',
#  'www.bancosabadelluk.com/cs/Satellite/BancoSabadellUK',
#  'www.bb.com.br/pbb/pagina-inicial/atendimento/bb-no-mundo/banco-do-brasil-in-london',
#  'www.bangkokbank.com',
# ...

# %%
lst=l[2:]

# %%
del lst[69]

# %%
data=pd.DataFrame(np.array(lst))

# %%
data.to_csv('/Users/noemiefabry/Desktop/Alex/urls_186_banks.csv')

# %%
data.head()
# Out:
#                                                    0
# 0  www.bank-abc.com/world/abcib/en/Pages/default....
# 1                                 www.abnamro.com/uk
# 2                       www.theaccessbankukltd.co.uk
# 3                                   www.adambank.com
# 4                                     www.adib.co.uk

# %%
def new_url(data_frame):
    lst1=[]
    for index,url in data_frame.iterrows():
        if 'http' not in url:
            url='https://'+url
            lst1.append(url)
        else:
            lst1.append(url)
    return pd.DataFrame(np.array(lst1))

# %%
new_url(data)
# Out:
#                                                      0
# 0    https://www.bank-abc.com/world/abcib/en/Pages/...
# 1                           https://www.abnamro.com/uk
# 2                 https://www.theaccessbankukltd.co.uk
# 3                             https://www.adambank.com
# 4                               https://www.adib.co.uk
# ..                                                 ...
# 178                         https://www.wesleyan.co.uk
# 179                         https://www.westpac.com.au
# 180                     https://www.wyelandsbank.co.uk
# 181                  https://www.secure.ybonline.co.uk
# 182                      https://www.zenith-bank.co.uk
#
# [183 rows x 1 columns]
