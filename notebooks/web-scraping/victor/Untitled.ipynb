# %%
import requests as req
from bs4 import BeautifulSoup
import selenium
from PIL import Image
import pandas as pd
import numpy as np
from selenium import webdriver
import time

# %%
FCA_flagged_prov = pd.read_csv('/Users/victorpalanco/Desktop/project-lewagon/data_19.csv')
FCA_flagged_prov['website'].head()
# Out:
# 0    ['https://cryptoforextrading50.com/']
# 1       ['www.cryptodigital-currency.com']
# 2               ['www.highstarinvest.com']
# 3           ['www.cryptoglobaltrade.live']
# 4            ['www.forexcryptopayout.com']
# Name: website, dtype: object

# %%
FCA_flagged_prov
# Out:
#     Unnamed: 0                 company name  \
# 0            0         CRYPTOFOREXTRADING50
# 1            1       Cryptodigital-currency
# 2            2           highstarinvest.com
# 3            3         CRYPTO GLOBAL TRADES
# 4            4          FOREX CRYPTO PAYOUT
# 5            5                 FXCFDTRADERS
# 6            6      zenithinvestmentpty.com
# 7            7                ALBITFX-TRADE
# 8            8                   EU FX BANK
# 9            9             Vadwell Trade Fx
# 10          10       REAL WEALTH INVESTMENT
# 11          11      exodusorbitalinvest.ltd
# 12          12           DIAMOND INVESTMENT
# 13          13           highstarinvest.com
# 14          14         vine-investments.com
# 15          15  cryptoinvestmentcapital.com
# 16          16           Great Western Bank
# 17          17              Excryptotradefx
# 18          18            UniversalSpotbank
# 19          19       CKB TRADERS INVESTMENT
#
#                                           fca website  \
# 0   https://www.fca.org.uk/news/warnings/cryptofor...
# 1   https://www.fca.org.uk/news/warnings/cryptodig...
# 2   https://www.fca.org.uk/news/warnings/highstari...
# 3   https://www.fca.org.uk/news/warnings/crypto-gl...
# 4   https://www.fca.org.uk/news/warnings/forex-cry...
# 5   https://www.fca.org.uk/news/warnings/fxcfdtraders
# 6   https://www.fca.org.uk/news/warnings/zenithinv...
# 7   https://www.fca.org.uk/news/warnings/albitfx-t...
# 8     https://www.fca.org.uk/news/warnings/eu-fx-bank
# 9   https://www.fca.org.uk/news/warnings/vadwell-t...
# 10  https://www.fca.org.uk/news/warnings/real-weal...
# 11  https://www.fca.org.uk/news/warnings/exodusorb...
# 12  https://www.fca.org.uk/news/warnings/diamond-i...
# 13  https://www.fca.org.uk/news/warnings/highstari...
# 14  https://www.fca.org.uk/news/warnings/vine-inve...
# 15  https://www.fca.org.uk/news/warnings/cryptoinv...
# 16  https://www.fca.org.uk/news/warnings/great-wes...
# 17  https://www.fca.org.uk/news/warnings/excryptot...
# 18  https://www.fca.org.uk/news/warnings/universal...
# 19  https://www.fca.org.uk/news/warnings/ckb-trade...
#
#                                               website
# 0               ['https://cryptoforextrading50.com/']
# 1                  ['www.cryptodigital-currency.com']
# 2                          ['www.highstarinvest.com']
# 3                      ['www.cryptoglobaltrade.live']
# 4                       ['www.forexcryptopayout.com']
# 5                     ['https://fxcfdtraders.co.uk/']
# 6                     ['www.zenithinvestmentpty.com']
# 7                        ['www.albitfx-trade.online']
# 8                           ['https://eufxbank.com/']
# 9                          ['www.vadwelltradefx.com']
# 10              ['https://realwealthinvestment.com/']
# 11                    ['www.exodusorbitalinvest.ltd']
# 12                    ['https://diamondforex.co.uk/']
# 13                         ['www.highstarinvest.com']
# 14  ['https://seainvention.wixsite.com/vine-invest...
# 15                ['www.cryptoinvestmentcapital.com']
# 16                   ['www.greatwesternintlbank.com']
# 17                ['https://excryptotradefx.online/']
# 18                 ['https://universalspotbank.com/']
# 19                  ['http://ckbmineinvestment.com/']

# %%
screenshots = []
